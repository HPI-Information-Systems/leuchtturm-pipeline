# %%
import pickle
import os
import pyLDAvis
import pyLDAvis.gensim

# %%
PATH_TO_FILES = '../models'
PATH_TO_TM = PATH_TO_FILES + '/topicmodel_enron.pickle'
PATH_TO_DICT = PATH_TO_FILES + '/topicdict_enron.pickle'
PATH_TO_CORPUS = PATH_TO_FILES + '/topiccorpus_enron.pickle'

# %%
with open(os.path.abspath(PATH_TO_TM), mode='rb') as pfile:
    model = pickle.load(pfile)
with open(os.path.abspath(PATH_TO_DICT), mode='rb') as pfile:
    dictionary = pickle.load(pfile)
with open(os.path.abspath(PATH_TO_CORPUS), mode='rb') as pfile:
    corpus = pickle.load(pfile)

# %%
new_model = pyLDAvis.gensim.prepare(model, corpus, dictionary)
# Out:
# /root/pipeline/lib/python3.5/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   return pd.concat([default_term_info] + list(topic_dfs))

# %%
PATH_TO_FILES = '../../historic_tm_dont_delete/5-d5ca4d793af8cb751f29a3f4ad634f04e463f100'
PATH_TO_TM = PATH_TO_FILES + '/topicmodel_enron.pickle'
PATH_TO_DICT = PATH_TO_FILES + '/topicdict_enron.pickle'
PATH_TO_CORPUS = PATH_TO_FILES + '/topiccorpus_enron.pickle'

# %%
with open(os.path.abspath(PATH_TO_TM), mode='rb') as pfile:
    model = pickle.load(pfile)
with open(os.path.abspath(PATH_TO_DICT), mode='rb') as pfile:
    dictionary = pickle.load(pfile)
with open(os.path.abspath(PATH_TO_CORPUS), mode='rb') as pfile:
    corpus = pickle.load(pfile)

# %%
old_model = pyLDAvis.gensim.prepare(model, corpus, dictionary)
# Out:
# /root/pipeline/lib/python3.5/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   return pd.concat([default_term_info] + list(topic_dfs))

# %%
pyLDAvis.display(old_model)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el238161403886516035522408867905"></div>
# <script type="text/javascript">
#
# ...

# %%
pyLDAvis.display(new_model)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el238161403886516039125127907326"></div>
# <script type="text/javascript">
#
# ...
